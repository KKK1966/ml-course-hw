# %% [markdown]
# Выводы
#
# 1. В этой работе я описал функции реализации метода MSE, MAE регуляризаторов по L1, L2 норме и их производные. Проверка показала что все функции описаны правильно.
# 2. Также нужно отметить что функции MAE и L1 норма не во всех точках дифференцируемы. В этих точках необходимо или дополнительно доопределять производные, или пользоваться понятием субградиента и субградиентными методами оптимизации.
# 3. Мы провели проверку наших функций MSE L2 и сравнили данные с sklearn. Расхождение незначительное. Оно связано с тем что мы не уитывали bias.
